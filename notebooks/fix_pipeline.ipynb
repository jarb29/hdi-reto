# %%
import dill
import pandas as pd

# %%
# Cargar el pipeline 1
with open('../pipes/pipeline_1.pkl', 'rb') as file:
    pipeline_1 = dill.load(file)

# %%
file = "../data/claims_dataset.csv"
df = pd.read_csv(file, sep="|")

df.shape
# Out:
# (10, 7)

# %%
df.head()
# Out:
#    claim_id marca_vehiculo  antiguedad_vehiculo  tipo_poliza  taller  \
# 0    561205           ferd                    1            1       4
# 1    528569           ferd                    4            3       1
# 2    408550            NaN                    2            4       1
# 3    208451            NaN                    1            1       4
# 4    394115           ferd                    2            4       1
#
#    partes_a_reparar  partes_a_reemplazar
# 0                 3                    2
# 1                 2                    4
# 2                 4                    2
# 3                 1                    4
# 4                 3                    4

# %%
df_1 = pipeline_1(df)

# %%
df_1.head()
# Out:
#    claim_id marca_vehiculo  antiguedad_vehiculo  tipo_poliza  taller  \
# 0    561205           ferd                    1            1       4
# 1    528569           ferd                    4            3       1
# 2    408550            NaN                    2            4       1
# 3    208451            NaN                    1            1       4
# 4    394115           ferd                    2            4       1
#
#    partes_a_reparar  partes_a_reemplazar  total_piezas
# 0                 3                    2             5
# 1                 2                    4             6
# 2                 4                    2             6
# 3                 1                    4             5
# 4                 3                    4             7

# %%
# Cargar el pipeline 2
with open('../pipes/pipeline_2.pkl', 'rb') as file:
    pipeline_2 = dill.load(file)

# %%
import numpy as np

# %%
df_2.head()
# Out:
#    claim_id marca_vehiculo  antiguedad_vehiculo  tipo_poliza  taller  \
# 0    561205           ferd                    1            1       4
# 1    528569           ferd                    4            3       1
# 2    408550            NaN                    2            4       1
# 3    208451            NaN                    1            1       4
# 4    394115           ferd                    2            4       1
#
#    partes_a_reparar  partes_a_reemplazar  total_piezas  log_total_piezas
# 0                 3                    2             5          1.609438
# 1                 2                    4             6          1.791759
# 2                 4                    2             6          1.791759
# 3                 1                    4             5          1.609438
# 4                 3                    4             7          1.945910

# %%
with open('../pipes/pipeline_3.pkl', 'rb') as file:
    pipeline_3 = dill.load(file)

# %%
df_3 = pipeline_3(df_2)

# %%
df_3.head()
# Out:
#    claim_id marca_vehiculo  antiguedad_vehiculo  tipo_poliza  taller  \
# 0    561205           ferd                    1            1       4
# 1    528569           ferd                    4            3       1
# 2    408550            NaN                    2            4       1
# 3    208451            NaN                    1            1       4
# 4    394115           ferd                    2            4       1
#
#    partes_a_reparar  partes_a_reemplazar  total_piezas  log_total_piezas  \
# 0                 3                    2             5          1.609438
# 1                 2                    4             6          1.791759
# 2                 4                    2             6          1.791759
# 3                 1                    4             5          1.609438
# 4                 3                    4             7          1.945910
#
#    marca_vehiculo_encoded
# 0                     3.0
# 1                     3.0
# 2                     NaN
# ...

# %%
with open('../pipes/pipeline_4.pkl', 'rb') as file:
    pipeline_4 = dill.load(file)

# %%
df_4 = pipeline_4(df_3)

# %%
df_4.head()
# Out:
#    claim_id marca_vehiculo  antiguedad_vehiculo  tipo_poliza  taller  \
# 0    561205           ferd                    1            1       4
# 1    528569           ferd                    4            3       1
# 2    408550            NaN                    2            4       1
# 3    208451            NaN                    1            1       4
# 4    394115           ferd                    2            4       1
#
#    partes_a_reparar  partes_a_reemplazar  total_piezas  log_total_piezas  \
# 0                 3                    2             5          1.609438
# 1                 2                    4             6          1.791759
# 2                 4                    2             6          1.791759
# 3                 1                    4             5          1.609438
# 4                 3                    4             7          1.945910
#
#    marca_vehiculo_encoded  valor_vehiculo  valor_por_pieza
# ...

# %%
with open('../pipes/pipeline_5.pkl', 'rb') as file:
    pipeline_5 = dill.load(file)

# %%
df_5 = pipeline_5(df_4)

# %%
df_5.head()
# Out:
#    claim_id marca_vehiculo  antiguedad_vehiculo  tipo_poliza  taller  \
# 0    561205           ferd                    1            1       4
# 1    528569           ferd                    4            3       1
# 2    408550            NaN                    2            4       1
# 3    208451            NaN                    1            1       4
# 4    394115           ferd                    2            4       1
#
#    partes_a_reparar  partes_a_reemplazar  total_piezas  log_total_piezas  \
# 0                 3                    2             5          1.609438
# 1                 2                    4             6          1.791759
# 2                 4                    2             6          1.791759
# 3                 1                    4             5          1.609438
# 4                 3                    4             7          1.945910
#
#    marca_vehiculo_encoded  valor_vehiculo  valor_por_pieza  \
# ...
